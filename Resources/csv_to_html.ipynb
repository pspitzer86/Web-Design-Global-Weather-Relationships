# %%
import pandas as pd

# %%
file = "Resources/new_cities.csv"

# %%
cities = pd.read_csv(file)
cities
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Tasiilaq  65.6145  -37.6368     17.60        45          54
# 1          Ushuaia -54.8000  -68.3000     53.60        54          75
# 2           Albany  42.6001  -73.9662     28.99        56         100
# 3           Sydney -33.8679  151.2073     75.99        60          20
# 4    Zelenoborskiy  66.8450   32.3622     -4.09        93          88
# ..             ...      ...       ...       ...       ...         ...
# 562            Hit  33.6416   42.8251     49.42        44          52
# 563     Eyrarbakki  63.8630  -21.1481     23.00        93          75
# 564         Nurota  40.5614   65.6886     19.40        73           0
# 565          Kromy  52.6876   35.7667     27.48        98         100
# 566    Kinablangan   7.6947  126.5503     79.47        75          46
#
#      Wind Speed Country        Date
# 0          4.61      GL  1610233700
# 1          6.91      AR  1610233762
# ...

# %%
cities['City ID'] = cities.index

# %%
cities=cities[['City ID','City', 'Country', 'Lat', 'Lng', 'Date', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed']]
cities
# Out:
#      City ID           City Country      Lat       Lng        Date  Max Temp  \
# 0          0       Tasiilaq      GL  65.6145  -37.6368  1610233700     17.60
# 1          1        Ushuaia      AR -54.8000  -68.3000  1610233762     53.60
# 2          2         Albany      US  42.6001  -73.9662  1610233601     28.99
# 3          3         Sydney      AU -33.8679  151.2073  1610234143     75.99
# 4          4  Zelenoborskiy      RU  66.8450   32.3622  1610234175     -4.09
# ..       ...            ...     ...      ...       ...         ...       ...
# 562      562            Hit      IQ  33.6416   42.8251  1610234286     49.42
# 563      563     Eyrarbakki      IS  63.8630  -21.1481  1610234326     23.00
# 564      564         Nurota      UZ  40.5614   65.6886  1610233926     19.40
# 565      565          Kromy      RU  52.6876   35.7667  1610234327     27.48
# 566      566    Kinablangan      PH   7.6947  126.5503  1610234327     79.47
#
#      Humidity  Cloudiness  Wind Speed
# ...

# %%
output_file = "new_cities.html"
cities.to_html(output_file, index=False)
